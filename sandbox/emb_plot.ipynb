# %%
# %cd ~/repo/protein-transfer
# Out:
# /home/t-fli/repo/protein-transfer

# %%
# %load_ext blackcellmagic

# %%
from scr.vis.emb_vis import Emb_Vis

# %%
import torch

# %%
model, alphabet = torch.hub.load("facebookresearch/esm:main", "esm1b_t33_650M_UR50S")
# Out:
# Using cache found in /home/t-fli/.cache/torch/hub/facebookresearch_esm_main

# %%
aa_emb = model.embed_tokens.weight.detach().cpu().numpy()[:20,:]
aa_emb.shape
# Out:
# (20, 1280)

# %%
esm_emb_vis_class = Emb_Vis(
    aa_emb = aa_emb,
    emb_name = "esm1b_t33_650M_UR50S input amino acids",
    subfolder = "esm",
)
# Out:
# WARNING: Consider installing the package MulticoreTSNE (https://github.com/DmitryUlyanov/Multicore-TSNE). Even for n_jobs=1 this speeds up the computation considerably and might yield better converged results.
# /anaconda/envs/protran/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# ... storing 'property' as categorical
# AnnData object with n_obs × n_vars = 20 × 1280
#     obs: 'property'
